# %%
import pandas as pd
import os

# %%
os.getcwd()
root_path = os.path.join(os.getcwd(),'..')

# %%
os.chdir(os.path.abspath(root_path))

# %%
df = pd.read_csv('211210-DRM-total.csv')

# %%
metal_df = df.iloc[:,2:25]
supporting_df = df.iloc[:,25:70]
pretreat_df = df.iloc[:,70:77]
operating_df = df.iloc[:,77:]

# %%
pretreat_df
# Out:
#       Preparation  Calcination T  Calcination time  Reduction T  \
# 0               4          700.0               5.0        800.0
# 1               4          700.0               5.0        800.0
# 2               4          700.0               5.0        800.0
# 3               4          700.0               5.0        800.0
# 4               4          700.0               5.0        800.0
# ...           ...            ...               ...          ...
# 5903            5          300.0               6.0       1000.0
# 5904            5          300.0               6.0       1000.0
# 5905            5          300.0               6.0       1000.0
# 5906            5          300.0               6.0       1000.0
# 5907            5          300.0               6.0       1000.0
#
#       Reduction time  Reduction H2  Reaction T
# 0                2.0         33.33       600.0
# 1                2.0         33.33       600.0
# 2                2.0         33.33       600.0
# ...
